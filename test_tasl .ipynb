# %%
import numpy as np 
import pandas as pd 
import xarray as xr

# %% [markdown]
# ### Task 1

# %%
data = xr.open_dataset("waves_2019-01-01.nc")

# %%
data_df = data.to_dataframe().reset_index()

# %%
data_0_0 = data_df[(data_df['latitude'] == 0.0) & (data_df['longitude'] == 0.0)]

data_0_0
# Out:
#          latitude  longitude                time      hmax         mwd  \
# 2427840       0.0        0.0 2019-01-01 00:00:00  2.080878  182.493088
# 2427841       0.0        0.0 2019-01-01 01:00:00  2.078691  182.295319
# 2427842       0.0        0.0 2019-01-01 02:00:00  2.076502  182.097565
# 2427843       0.0        0.0 2019-01-01 03:00:00  2.076064  181.888809
# 2427844       0.0        0.0 2019-01-01 04:00:00  2.077815  181.663574
# 2427845       0.0        0.0 2019-01-01 05:00:00  2.079565  181.449326
# 2427846       0.0        0.0 2019-01-01 06:00:00  2.083942  181.235092
# 2427847       0.0        0.0 2019-01-01 07:00:00  2.090508  180.998871
# 2427848       0.0        0.0 2019-01-01 08:00:00  2.101013  180.784622
# 2427849       0.0        0.0 2019-01-01 09:00:00  2.110205  180.564880
# 2427850       0.0        0.0 2019-01-01 10:00:00  2.120272  180.378098
# 2427851       0.0        0.0 2019-01-01 11:00:00  2.142157  180.229782
# ...

# %%
data_0_0['hmax'].values
# Out:
# array([2.0808783, 2.0786905, 2.0765018, 2.076064 , 2.077815 , 2.079565 ,
#        2.0839424, 2.0905075, 2.1010132, 2.1102047, 2.1202717, 2.1421566,
#        2.1710443, 2.1946802, 2.2047472, 2.213502 , 2.233636 , 2.2507057,
#        2.268652 , 2.2795944, 2.2909746, 2.3041058, 2.3194246, 2.3259907],
#       dtype=float32)

# %% [markdown]
# ### Task 2

# %%
import requests

# %%
url = 'https://europe-west1-freesolarcalc.cloudfunctions.net/wave_max/'
params = {"lat":4.0, "lon":1.3}
res = requests.get(url, params)
print(res.text)
# Out:
# {"2009":4.870349884033203,"2010":4.449041366577148,"2011":5.537721633911133,"2012":5.245943069458008,"2013":5.48573112487793,"2014":5.522931098937988,"2015":5.0021209716796875,"2016":5.170196533203125,"2017":5.556546211242676,"2018":4.7959489822387695,"2019":4.951474189758301}
